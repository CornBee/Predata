# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/HOME_전력거래_연료비용.csv', encoding = 'cp949')

# %%
df
# Out:
#          기간         연료단가   Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5  \
# 0       NaN          원자력          유연탄          무연탄           유류          LNG
# 1       NaN        원/kWh        원/ton        원/ton         원/kl        원/ton
# 2   2018/12        5.847   140694.296   185557.605    740967.73   827983.687
# 3   2018/11        5.844    140103.67    178322.55   735055.293   773508.071
# 4   2018/10       5.8428  138921.3905  188445.1388  724956.2971  748848.0691
# ..      ...          ...          ...          ...          ...          ...
# 69  2013/05  4.465005714  91783.83312  159742.9098  918557.0779  1053437.867
# 70  2013/04  4.435291967  90248.61791  164690.8551  920513.9306   1048822.14
# 71  2013/03   4.40428799  95610.09442  164235.2945  888435.9981  1026930.566
# 72  2013/02  4.356258206  92797.80869  166184.2316  894002.2858  980258.1382
# 73  2013/01  4.319404801   95421.7497  156076.5996  911391.4189  851084.7269
#
# ...

# %%
df.columns.get_loc("Unnamed: 2")
# Out:
# 2

# %%
df['기간'] = pd.to_datetime(df['기간'])
df
# Out:
#            기간         연료단가   Unnamed: 2   Unnamed: 3   Unnamed: 4  \
# 0         NaT          원자력          유연탄          무연탄           유류
# 1         NaT        원/kWh        원/ton        원/ton         원/kl
# 2  2018-12-01        5.847   140694.296   185557.605    740967.73
# 3  2018-11-01        5.844    140103.67    178322.55   735055.293
# 4  2018-10-01       5.8428  138921.3905  188445.1388  724956.2971
# ..        ...          ...          ...          ...          ...
# 69 2013-05-01  4.465005714  91783.83312  159742.9098  918557.0779
# 70 2013-04-01  4.435291967  90248.61791  164690.8551  920513.9306
# 71 2013-03-01   4.40428799  95610.09442  164235.2945  888435.9981
# 72 2013-02-01  4.356258206  92797.80869  166184.2316  894002.2858
# 73 2013-01-01  4.319404801   95421.7497  156076.5996  911391.4189
#
#      Unnamed: 5         열량단가   Unnamed: 7   Unnamed: 8   Unnamed: 9  \
# 0           LNG          원자력          유연탄          무연탄           유류
# ...

# %%
df.columns = df.iloc[0]
df.head(3)
# Out:
# 0        NaN    원자력         유연탄         무연탄         유류         LNG      원자력  \
# 0        NaT    원자력         유연탄         무연탄         유류         LNG      원자력
# 1        NaT  원/kWh       원/ton       원/ton       원/kl       원/ton   원/Gcal
# 2 2018-12-01  5.847  140694.296  185557.605  740967.73  827983.687  2358.06
#
# 0       유연탄       무연탄        유류       LNG    원자력    유연탄    무연탄      유류     LNG
# 0       유연탄       무연탄        유류       LNG    원자력    유연탄    무연탄      유류     LNG
# 1    원/Gcal    원/Gcal    원/Gcal    원/Gcal  원/kWh  원/kWh  원/kWh   원/kWh   원/kWh
# 2  25876.43  27495.52  73126.38  64527.96   5.85  58.48  69.21  191.81  114.05

# %%
df.columns
# Out:
# Index([  NaT, '원자력', '유연탄', '무연탄',  '유류', 'LNG', '원자력', '유연탄', '무연탄',  '유류',
#        'LNG', '원자력', '유연탄', '무연탄',  '유류', 'LNG'],
#       dtype='object', name=0)

# %%
df.head(3)
# Out:
# 0        NaN    원자력         유연탄         무연탄         유류         LNG      원자력  \
# 0        NaT    원자력         유연탄         무연탄         유류         LNG      원자력
# 1        NaT  원/kWh       원/ton       원/ton       원/kl       원/ton   원/Gcal
# 2 2018-12-01  5.847  140694.296  185557.605  740967.73  827983.687  2358.06
#
# 0       유연탄       무연탄        유류       LNG    원자력    유연탄    무연탄      유류     LNG
# 0       유연탄       무연탄        유류       LNG    원자력    유연탄    무연탄      유류     LNG
# 1    원/Gcal    원/Gcal    원/Gcal    원/Gcal  원/kWh  원/kWh  원/kWh   원/kWh   원/kWh
# 2  25876.43  27495.52  73126.38  64527.96   5.85  58.48  69.21  191.81  114.05

# %%
df.isnull().sum()
# Out:
# 0
# NaN    2
# 원자력    0
# 유연탄    0
# 무연탄    0
# 유류     0
# LNG    0
# 원자력    0
# 유연탄    0
# 무연탄    0
# 유류     0
# LNG    0
# 원자력    0
# 유연탄    0
# 무연탄    0
# 유류     0
# LNG    0
# dtype: int64

# %%
df.columns
# Out:
# Index([  NaT, '원자력', '유연탄', '무연탄',  '유류', 'LNG', '원자력', '유연탄', '무연탄',  '유류',
#        'LNG', '원자력', '유연탄', '무연탄',  '유류', 'LNG'],
#       dtype='object', name=0)

# %%
df.columns = df.columns.fillna('기간')
df
# Out:
# 0          기간          원자력          유연탄          무연탄           유류  \
# 0         NaT          원자력          유연탄          무연탄           유류
# 1         NaT        원/kWh        원/ton        원/ton         원/kl
# 2  2018-12-01        5.847   140694.296   185557.605    740967.73
# 3  2018-11-01        5.844    140103.67    178322.55   735055.293
# 4  2018-10-01       5.8428  138921.3905  188445.1388  724956.2971
# ..        ...          ...          ...          ...          ...
# 69 2013-05-01  4.465005714  91783.83312  159742.9098  918557.0779
# 70 2013-04-01  4.435291967  90248.61791  164690.8551  920513.9306
# 71 2013-03-01   4.40428799  95610.09442  164235.2945  888435.9981
# 72 2013-02-01  4.356258206  92797.80869  166184.2316  894002.2858
# 73 2013-01-01  4.319404801   95421.7497  156076.5996  911391.4189
#
# 0           LNG          원자력          유연탄          무연탄           유류  \
# 0           LNG          원자력          유연탄          무연탄           유류
# ...

# %%
df = df.drop(labels=[0, 1], axis=0) # row 드롭 위해선 label

# %%
df
# Out:
# 0          기간          원자력          유연탄          무연탄           유류  \
# 2  2018-12-01        5.847   140694.296   185557.605    740967.73
# 3  2018-11-01        5.844    140103.67    178322.55   735055.293
# 4  2018-10-01       5.8428  138921.3905  188445.1388  724956.2971
# 5  2018-09-01         5.84    133207.25    183501.03    680428.08
# 6  2018-08-01         5.84    133781.25    184009.49    621191.32
# ..        ...          ...          ...          ...          ...
# 69 2013-05-01  4.465005714  91783.83312  159742.9098  918557.0779
# 70 2013-04-01  4.435291967  90248.61791  164690.8551  920513.9306
# 71 2013-03-01   4.40428799  95610.09442  164235.2945  888435.9981
# 72 2013-02-01  4.356258206  92797.80869  166184.2316  894002.2858
# 73 2013-01-01  4.319404801   95421.7497  156076.5996  911391.4189
#
# 0           LNG          원자력          유연탄          무연탄           유류  \
# 2    827983.687      2358.06     25876.43     27495.52     73126.38
# ...

# %%
for i in range(df.columns.get_loc("원자력"), len(df1.columns)):
    df.columns.values[i] =  '연료단가_' + df.columns.values[i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5d4142d840bc> in <module>
# ----> 1 for i in range(df.columns.get_loc("원자력"), len(df1.columns)):
#       2     df.columns.values[i] =  '연료단가_' + df.columns.values[i]
#
# NameError: name 'df1' is not defined
