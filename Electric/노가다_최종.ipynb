# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/HOME_전력거래_정산단가_연료원별.csv', encoding = 'cp949')

# %%
df.head()
# Out:
#         기간   지역        원자력        유연탄         무연탄          유류         LNG  \
# 0      NaN  NaN        NaN        NaN         NaN         NaN         NaN
# 1  2021/09   합계  32.740077  94.728006  115.703868  213.888207  125.427094
# 2  2021/08   합계  40.967125  99.643992  109.687386  532.428065  141.931066
# 3  2021/07   합계  64.284447  99.914346   99.605518  212.504026  121.216983
# 4  2021/06   합계  69.586483  91.967982   87.978433  183.701421  101.198998
#
#            양수         신재생  Unnamed: 9 Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0         NaN        연료전지       석탄가스화          태양           풍력           수력
# 1  130.291434  96.7323837  97.0709028  98.7403649  101.3614549  109.2927563
# 2  163.840472  92.6850495  92.7576511  97.9136241  100.6974973  114.3688235
# 3  137.929163  86.1050101  90.2787505   91.089834     92.72835  104.7636151
# 4  102.767284  82.1299504        87.5   83.944343   86.6458097   90.9281638
#
#   Unnamed: 13  Unnamed: 14 Unnamed: 15          기타         합계
# ...

# %%
list(df.columns)
# Out:
# ['기간',
#  '지역',
#  '원자력',
#  '유연탄',
#  '무연탄',
#  '유류',
#  'LNG',
#  '양수',
#  '신재생',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  '기타',
#  '합계']

# %%
t = ['연료전지', '석탄가스화', '태양', '풍력', '수력', '해양', '바이오', '폐기물']

# %%
t1 = ['신재생_' + sub for sub in t]
t1
# Out:
# ['신재생_연료전지',
#  '신재생_석탄가스화',
#  '신재생_태양',
#  '신재생_풍력',
#  '신재생_수력',
#  '신재생_해양',
#  '신재생_바이오',
#  '신재생_폐기물']

# %%
t3 = ['기간', '지역', '원자력', '유연탄', '무연탄', '유류', 'LNG', '양수']

# %%
t2 = t3 + t1 + ['기타', '합계']

# %%
df.set_axis([t2], axis='columns', inplace = True)

# %%
df
# Out:
#           기간   지역        원자력        유연탄         무연탄          유류         LNG  \
# 0        NaN  NaN        NaN        NaN         NaN         NaN         NaN
# 1    2021/09   합계  32.740077  94.728006  115.703868  213.888207  125.427094
# 2    2021/08   합계  40.967125  99.643992  109.687386  532.428065  141.931066
# 3    2021/07   합계  64.284447  99.914346   99.605518  212.504026  121.216983
# 4    2021/06   합계  69.586483  91.967982   87.978433  183.701421  101.198998
# ..       ...  ...        ...        ...         ...         ...         ...
# 233  2002/05   합계  39.371855  41.660467   48.691511   66.755077   75.689799
# 234  2002/04   합계  40.299890  41.600401   50.465364   60.490947   73.211908
# 235  2002/03   합계  39.351880  42.088690   51.118453   62.854301   74.247935
# 236  2002/02   합계  38.932937  42.394581   54.243727   71.515871   79.340000
# 237  2002/01   합계  40.212111  41.905286   48.963261   72.521700   79.256818
#
# ...

# %%
df.drop(index = df.index[0], axis = '0', inplace = True)

# %%
df
# Out:
#           기간  지역        원자력        유연탄         무연탄          유류         LNG  \
# 1    2021/09  합계  32.740077  94.728006  115.703868  213.888207  125.427094
# 2    2021/08  합계  40.967125  99.643992  109.687386  532.428065  141.931066
# 3    2021/07  합계  64.284447  99.914346   99.605518  212.504026  121.216983
# 4    2021/06  합계  69.586483  91.967982   87.978433  183.701421  101.198998
# 5    2021/05  합계  64.648106  84.965067   83.146085  163.528409   94.278881
# ..       ...  ..        ...        ...         ...         ...         ...
# 233  2002/05  합계  39.371855  41.660467   48.691511   66.755077   75.689799
# 234  2002/04  합계  40.299890  41.600401   50.465364   60.490947   73.211908
# 235  2002/03  합계  39.351880  42.088690   51.118453   62.854301   74.247935
# 236  2002/02  합계  38.932937  42.394581   54.243727   71.515871   79.340000
# 237  2002/01  합계  40.212111  41.905286   48.963261   72.521700   79.256818
#
# ...

# %%
df1 = df.drop(['지역', '합계'], axis = 1)
# Out:
# C:\Users\coding\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
df1
# Out:
#           기간        원자력        유연탄         무연탄          유류         LNG  \
# 1    2021/09  32.740077  94.728006  115.703868  213.888207  125.427094
# 2    2021/08  40.967125  99.643992  109.687386  532.428065  141.931066
# 3    2021/07  64.284447  99.914346   99.605518  212.504026  121.216983
# 4    2021/06  69.586483  91.967982   87.978433  183.701421  101.198998
# 5    2021/05  64.648106  84.965067   83.146085  163.528409   94.278881
# ..       ...        ...        ...         ...         ...         ...
# 233  2002/05  39.371855  41.660467   48.691511   66.755077   75.689799
# 234  2002/04  40.299890  41.600401   50.465364   60.490947   73.211908
# 235  2002/03  39.351880  42.088690   51.118453   62.854301   74.247935
# 236  2002/02  38.932937  42.394581   54.243727   71.515871   79.340000
# 237  2002/01  40.212111  41.905286   48.963261   72.521700   79.256818
#
#              양수    신재생_연료전지   신재생_석탄가스화      신재생_태양       신재생_풍력       신재생_수력  \
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# 기간            object
# 원자력          float64
# 유연탄          float64
# 무연탄          float64
# 유류           float64
# LNG          float64
# 양수           float64
# 신재생_연료전지      object
# 신재생_석탄가스화     object
# 신재생_태양        object
# 신재생_풍력        object
# 신재생_수력        object
# 신재생_해양        object
# 신재생_바이오       object
# 신재생_폐기물       object
# 기타           float64
# dtype: object

# %%
df1.columns = ['기간', '원자력', '유연탄', '무연탄', '유류', 'LNG', '양수', '신재생_연료전지', '신재생_석탄가스화', '신재생_태양', '신재생_풍력', '신재생_수력', '신재생_해양', '신재생_바이오', '신재생_폐기물', '기타']

# %%
df1.columns
# Out:
# Index(['기간', '원자력', '유연탄', '무연탄', '유류', 'LNG', '양수', '신재생_연료전지', '신재생_석탄가스화',
#        '신재생_태양', '신재생_풍력', '신재생_수력', '신재생_해양', '신재생_바이오', '신재생_폐기물', '기타'],
#       dtype='object')

# %%
df1['기간'] = pd.to_datetime(df1['기간'])
df1
# Out:
#             기간        원자력        유연탄         무연탄          유류         LNG  \
# 1   2021-09-01  32.740077  94.728006  115.703868  213.888207  125.427094
# 2   2021-08-01  40.967125  99.643992  109.687386  532.428065  141.931066
# 3   2021-07-01  64.284447  99.914346   99.605518  212.504026  121.216983
# 4   2021-06-01  69.586483  91.967982   87.978433  183.701421  101.198998
# 5   2021-05-01  64.648106  84.965067   83.146085  163.528409   94.278881
# ..         ...        ...        ...         ...         ...         ...
# 233 2002-05-01  39.371855  41.660467   48.691511   66.755077   75.689799
# 234 2002-04-01  40.299890  41.600401   50.465364   60.490947   73.211908
# 235 2002-03-01  39.351880  42.088690   51.118453   62.854301   74.247935
# 236 2002-02-01  38.932937  42.394581   54.243727   71.515871   79.340000
# 237 2002-01-01  40.212111  41.905286   48.963261   72.521700   79.256818
#
#              양수    신재생_연료전지   신재생_석탄가스화      신재생_태양       신재생_풍력       신재생_수력  \
# ...

# %%
df2 = df1[( '2013-01' <= (df1['기간']) ) & ( (df1['기간']) < '2019-01' )]

# %%
df2.reset_index(drop = True)
# Out:
#            기간        원자력        유연탄         무연탄          유류         LNG  \
# 0  2018-12-01  71.868733  78.878210  126.712104  251.178571  144.157013
# 1  2018-11-01  62.601931  73.681336  113.803490  238.316271  126.034212
# 2  2018-10-01  58.211429  70.700303  107.257637  174.500232  117.069142
# 3  2018-09-01  55.483345  70.507718  103.457518  272.739516  124.476471
# 4  2018-08-01  61.733139  80.414530  102.050984  194.298266  124.445349
# ..        ...        ...        ...         ...         ...         ...
# 67 2013-05-01  47.976032  61.544745   90.108727  230.185168  156.462334
# 68 2013-04-01  51.310672  62.231395   96.854651  219.936481  165.643771
# 69 2013-03-01  48.475979  63.307329   91.806427  213.734439  162.366976
# 70 2013-02-01  48.244129  61.729563  101.309650  212.732298  160.602214
# 71 2013-01-01  52.670652  67.114923  105.351877  232.311789  164.650065
#
#             양수     신재생_연료전지    신재생_석탄가스화       신재생_태양       신재생_풍력  \
# ...

# %%
df2.isnull().sum()
# Out:
# 기간           0
# 원자력          0
# 유연탄          0
# 무연탄          0
# 유류           0
# LNG          0
# 양수           0
# 신재생_연료전지     0
# 신재생_석탄가스화    0
# 신재생_태양       0
# 신재생_풍력       0
# 신재생_수력       0
# 신재생_해양       0
# 신재생_바이오      0
# 신재생_폐기물      0
# 기타           9
# dtype: int64

# %%
df2 = df2.sort_values(by = '기간')
df2
# Out:
#             기간        원자력        유연탄         무연탄          유류         LNG  \
# 105 2013-01-01  52.670652  67.114923  105.351877  232.311789  164.650065
# 104 2013-02-01  48.244129  61.729563  101.309650  212.732298  160.602214
# 103 2013-03-01  48.475979  63.307329   91.806427  213.734439  162.366976
# 102 2013-04-01  51.310672  62.231395   96.854651  219.936481  165.643771
# 101 2013-05-01  47.976032  61.544745   90.108727  230.185168  156.462334
# ..         ...        ...        ...         ...         ...         ...
# 38  2018-08-01  61.733139  80.414530  102.050984  194.298266  124.445349
# 37  2018-09-01  55.483345  70.507718  103.457518  272.739516  124.476471
# 36  2018-10-01  58.211429  70.700303  107.257637  174.500232  117.069142
# 35  2018-11-01  62.601931  73.681336  113.803490  238.316271  126.034212
# 34  2018-12-01  71.868733  78.878210  126.712104  251.178571  144.157013
#
#              양수     신재생_연료전지    신재생_석탄가스화       신재생_태양       신재생_풍력  \
# ...

# %%
df2.to_csv('정산단가_연료원별_null.csv', index = False, encoding = 'cp949')
