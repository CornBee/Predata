# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('data/HOME_전력거래_정산단가_연료원별.csv', encoding = 'cp949')

# %%
df.head(3)
# Out:
#         기간   지역        원자력        유연탄         무연탄          유류         LNG  \
# 0      NaN  NaN        NaN        NaN         NaN         NaN         NaN
# 1  2021/09   합계  32.740077  94.728006  115.703868  213.888207  125.427094
# 2  2021/08   합계  40.967125  99.643992  109.687386  532.428065  141.931066
#
#            양수         신재생  Unnamed: 9 Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0         NaN        연료전지       석탄가스화          태양           풍력           수력
# 1  130.291434  96.7323837  97.0709028  98.7403649  101.3614549  109.2927563
# 2  163.840472  92.6850495  92.7576511  97.9136241  100.6974973  114.3688235
#
#   Unnamed: 13  Unnamed: 14 Unnamed: 15          기타         합계
# 0          해양          바이오         폐기물         NaN        NaN
# 1  93.3066187  150.9736834           0  100.621055  88.371779
# 2  91.6457939   156.942158           0   98.206236  98.448852

# %%
df.columns
# Out:
# Index(['기간', '지역', '원자력', '유연탄', '무연탄', '유류', 'LNG', '양수', '신재생', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', '기타', '합계'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# 기간               NaN
# 지역               NaN
# 원자력              NaN
# 유연탄              NaN
# 무연탄              NaN
# 유류               NaN
# LNG              NaN
# 양수               NaN
# 신재생             연료전지
# Unnamed: 9     석탄가스화
# Unnamed: 10       태양
# Unnamed: 11       풍력
# Unnamed: 12       수력
# Unnamed: 13       해양
# Unnamed: 14      바이오
# Unnamed: 15      폐기물
# 기타               NaN
# 합계               NaN
# Name: 0, dtype: object

# %%
t = df.iloc[0].dropna()
t = list(t)
t.remove('연료전지')
print(t)
# Out:
# ['석탄가스화', '태양', '풍력', '수력', '해양', '바이오', '폐기물']

# %%
df.columns.get_loc("신재생")
# Out:
# 8

# %%
col = df.filter(like = "Unnamed")
col
# Out:
#      Unnamed: 9 Unnamed: 10  Unnamed: 11  Unnamed: 12 Unnamed: 13  \
# 0         석탄가스화          태양           풍력           수력          해양
# 1    97.0709028  98.7403649  101.3614549  109.2927563  93.3066187
# 2    92.7576511  97.9136241  100.6974973  114.3688235  91.6457939
# 3    90.2787505   91.089834     92.72835  104.7636151   85.034383
# 4          87.5   83.944343   86.6458097   90.9281638  81.2522193
# ..          ...         ...          ...          ...         ...
# 233           0           0            0   58.9023765           0
# 234           0           0            0   56.6115991           0
# 235           0           0            0   60.5903633           0
# 236           0           0            0   60.5317227           0
# 237           0           0            0   67.2300531           0
#
#      Unnamed: 14 Unnamed: 15
# 0            바이오         폐기물
# 1    150.9736834           0
# 2     156.942158           0
# 3     142.752771           0
# ...

# %%
df.drop(columns = col, inplace = True)
df
# Out:
#           기간   지역        원자력        유연탄         무연탄          유류         LNG  \
# 0        NaN  NaN        NaN        NaN         NaN         NaN         NaN
# 1    2021/09   합계  32.740077  94.728006  115.703868  213.888207  125.427094
# 2    2021/08   합계  40.967125  99.643992  109.687386  532.428065  141.931066
# 3    2021/07   합계  64.284447  99.914346   99.605518  212.504026  121.216983
# 4    2021/06   합계  69.586483  91.967982   87.978433  183.701421  101.198998
# ..       ...  ...        ...        ...         ...         ...         ...
# 233  2002/05   합계  39.371855  41.660467   48.691511   66.755077   75.689799
# 234  2002/04   합계  40.299890  41.600401   50.465364   60.490947   73.211908
# 235  2002/03   합계  39.351880  42.088690   51.118453   62.854301   74.247935
# 236  2002/02   합계  38.932937  42.394581   54.243727   71.515871   79.340000
# 237  2002/01   합계  40.212111  41.905286   48.963261   72.521700   79.256818
#
#              양수         신재생          기타         합계
# ...

# %%
df.rename(columns={'신재생': '신재생_연료전지'}, inplace=True)
df
# Out:
#           기간   지역        원자력        유연탄         무연탄          유류         LNG  \
# 0        NaN  NaN        NaN        NaN         NaN         NaN         NaN
# 1    2021/09   합계  32.740077  94.728006  115.703868  213.888207  125.427094
# 2    2021/08   합계  40.967125  99.643992  109.687386  532.428065  141.931066
# 3    2021/07   합계  64.284447  99.914346   99.605518  212.504026  121.216983
# 4    2021/06   합계  69.586483  91.967982   87.978433  183.701421  101.198998
# ..       ...  ...        ...        ...         ...         ...         ...
# 233  2002/05   합계  39.371855  41.660467   48.691511   66.755077   75.689799
# 234  2002/04   합계  40.299890  41.600401   50.465364   60.490947   73.211908
# 235  2002/03   합계  39.351880  42.088690   51.118453   62.854301   74.247935
# 236  2002/02   합계  38.932937  42.394581   54.243727   71.515871   79.340000
# 237  2002/01   합계  40.212111  41.905286   48.963261   72.521700   79.256818
#
#              양수    신재생_연료전지          기타         합계
# ...

# %%
col.set_axis([t], axis='columns', inplace = True)
col
# Out:
#           석탄가스화          태양           풍력           수력          해양  \
# 0         석탄가스화          태양           풍력           수력          해양
# 1    97.0709028  98.7403649  101.3614549  109.2927563  93.3066187
# 2    92.7576511  97.9136241  100.6974973  114.3688235  91.6457939
# 3    90.2787505   91.089834     92.72835  104.7636151   85.034383
# 4          87.5   83.944343   86.6458097   90.9281638  81.2522193
# ..          ...         ...          ...          ...         ...
# 233           0           0            0   58.9023765           0
# 234           0           0            0   56.6115991           0
# 235           0           0            0   60.5903633           0
# 236           0           0            0   60.5317227           0
# 237           0           0            0   67.2300531           0
#
#              바이오  폐기물
# 0            바이오  폐기물
# 1    150.9736834    0
# 2     156.942158    0
# 3     142.752771    0
# 4    125.5759618    0
# ..           ...  ...
# ...

# %%
# add_prefix() , add_suffix()
col = col.add_prefix('신재생_')

# %%
data = df.join(col)

# %%
data
# Out:
#           기간   지역        원자력        유연탄         무연탄          유류         LNG  \
# 0        NaN  NaN        NaN        NaN         NaN         NaN         NaN
# 1    2021/09   합계  32.740077  94.728006  115.703868  213.888207  125.427094
# 2    2021/08   합계  40.967125  99.643992  109.687386  532.428065  141.931066
# 3    2021/07   합계  64.284447  99.914346   99.605518  212.504026  121.216983
# 4    2021/06   합계  69.586483  91.967982   87.978433  183.701421  101.198998
# ..       ...  ...        ...        ...         ...         ...         ...
# 233  2002/05   합계  39.371855  41.660467   48.691511   66.755077   75.689799
# 234  2002/04   합계  40.299890  41.600401   50.465364   60.490947   73.211908
# 235  2002/03   합계  39.351880  42.088690   51.118453   62.854301   74.247935
# 236  2002/02   합계  38.932937  42.394581   54.243727   71.515871   79.340000
# 237  2002/01   합계  40.212111  41.905286   48.963261   72.521700   79.256818
#
# ...

# %%
data.drop(index=data.index[0], 
        axis=0, 
        inplace=True)
data
# Out:
#           기간  지역        원자력        유연탄         무연탄          유류         LNG  \
# 1    2021/09  합계  32.740077  94.728006  115.703868  213.888207  125.427094
# 2    2021/08  합계  40.967125  99.643992  109.687386  532.428065  141.931066
# 3    2021/07  합계  64.284447  99.914346   99.605518  212.504026  121.216983
# 4    2021/06  합계  69.586483  91.967982   87.978433  183.701421  101.198998
# 5    2021/05  합계  64.648106  84.965067   83.146085  163.528409   94.278881
# ..       ...  ..        ...        ...         ...         ...         ...
# 233  2002/05  합계  39.371855  41.660467   48.691511   66.755077   75.689799
# 234  2002/04  합계  40.299890  41.600401   50.465364   60.490947   73.211908
# 235  2002/03  합계  39.351880  42.088690   51.118453   62.854301   74.247935
# 236  2002/02  합계  38.932937  42.394581   54.243727   71.515871   79.340000
# 237  2002/01  합계  40.212111  41.905286   48.963261   72.521700   79.256818
#
# ...
